# %% [markdown]
# *Assigment Instructions
#
# # Text Adventure Game Development
#
# This assigment has been elaborated by Jose Luis Palacios Gonzalez
#
# 10/18/2020

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %%
"""
docstring:

A) “The heart break” is a Text Adventure game which simulates real life heart break situation of a human being and a series of un/fortunate decisions that led him to his final destiny. The game consist of a 3 stage game, where you are ask to different questions and depending your answer the different paths that the game will take you too.
     o Stage_0= Intro
     o Stage_1 = A bench in the park
     o Stage_2 = Party with Roxanne
     o Stage_3 = Outside your house

B) Known Bugs and/or Errors:

     o Spelling and syntax errors.
"""

#!# PLEASE RUN THIS FIRST #!#


#We run this to create an easy way to add colors to our game
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    
import time
import random
import pandas as pd

# %%
#Game intro - Press Start
def press_start():
    
    #Color blue - Press start message and input
    print(f"{bcolors.OKBLUE} Please type start \n")
    start = input(prompt = ">>>  ")
    start = start.lower()
    
    # Conditional input - Press Start
    
    if "start" in start:
        
        # if start ---> Start game!
        stage_0()

    elif "no" in start:
        #if no ---> take me out
        fail_1() 
    
    else:
        #incorrect entry
        print(f"{bcolors.WARNING}Invalid entry. Please try typing >start< again.")
        press_start()
        
def fail_1():
    #print statment whe "no" at press start
    print(f"""{bcolors.HEADER}It okay if you dont want to play, run the code again if you change your mind!!""")

def stage_0():
    
    #Visual Effect for the into
    telon = 2

    while telon > 0:
        print(".")
        time.sleep(0.3)
        print(".")
        time.sleep( 0.3 )
        telon -=1
    user_name()

def user_name():
 #User input - This way you'll have a name in the game   
    user = input(prompt=f"{bcolors.ENDC} Could you please write your name? ")
    user = user.capitalize()
    
    #Confirm user name
    print(f"You typed {user}, is that correct? (yes / no)")
    
    userconf = input(prompt=">>>")
    userconf = userconf.casefold()
    
    #conditional user confirmation
    if "yes" in userconf:
        print(f"Thanks {user}!")
        
        #Visual Effect
        telon = 3
        while telon > 0:
            print(".")
            time.sleep(0.3)
            print(".")
            time.sleep( 0.3 )
            telon -=1
          
        #Game Intro
        t=0.3
        time.sleep(t)
        print(".... Long.")
        time.sleep(t)
        print("......... Long.")
        time.sleep(t)
        print ("............ Long time ago.") 
        time.sleep(t)
        print("Well, maybe around a year. Nevermind.") #joke
        time.sleep(t+0.3)
        print("It was a cold november afternoon when I received that hurtful message.")
        time.sleep(t)
        print(f"The message that starts with '{user} we need to talk'.")
        time.sleep(t)
        print("There I was, sitting in that bench in the middle of the park.")
        time.sleep(t)
        print("Around me, kids laughing, family reunions, lovely dogs chasing their tail.")
        time.sleep(t)
        print("Everyone so happy, but me.")
        time.sleep(t) 
        print("While seconds turned it minutes, and minutes turn into hours.") 
        time.sleep(t) 
        print("I could not think on anything else but the terrible feeling of a broken heart")
        time.sleep(t)
        print("Suddenly, someone approaches me.")
        time.sleep(t)
        
        #First interaction
        print(f"Old Person:{bcolors.HEADER} May I sit with you? (yes/no)")
        
        answer1 = input(prompt="")
        answer1 = answer1.casefold()
        
        if "yes" in answer1:
            #Old person sitts next to you
            time.sleep(t)
            stage_1(user)

        elif "no" in answer1:
            #Old person is offended
            print(f"{bcolors.OKBLUE}Old Person:{bcolors.HEADER}Don't have to be rude, I will be quick then. Your money or your life!!!")
            time.sleep(t)
            fail_2()

        else:
            #You dont respond, old person ask for money
            print(f"{bcolors.OKBLUE}Old Person:{bcolors.HEADER}Sorry, I don't mean to bother, could you spare me a coin please? (yes/no)")
            time.sleep(t)
            fail_3()
            
    #User Name Confirmation Condicional    
    elif "no" in userconf:
        #If no ---> retype it
        print(f"{bcolors.WARNING}No problem, let's try again.\n")
        user_name()
        
    else:
        #else ---> Invalid entry
        print(f"{bcolors.WARNING}Invalid entry. Please try typing again.")
        user_name()

#Fail 3  - Wrong anwswer at the park 2 
def fail_3():
    coin = input(prompt= f"{bcolors.OKBLUE}Will you spare him a coin? ")
    coin = coin.casefold()
    
    if "yes" in coin:
        print(f"{bcolors.OKBLUE}Old Person:{bcolors.HEADER} thanks! God blessings!")
        print(f"""
    _______________________________________________________________________
    
    {bcolors.WARNING} You made the noble choice!
    
    {bcolors.HEADER} The old person takes the money and leaves...  
    Nevertheless, you stay in the bench for 15 min more and leave with 
    nothing but pain from your heartache...

    {bcolors.BOLD}{bcolors.OKCYAN} G A M E    O V E R   !! 
    _______________________________________________________________________ 
     
    """)
        play_again()    
    else:
        print(f"{bcolors.OKBLUE}Old Person:{bcolors.HEADER}Don't have to be rude, I will be quick then. Your money or your life!!!")
        time.sleep(t)
        fail_2()
#Fail 2  - Wrong anwswer at the park 1
def fail_2():
    print(f"""
    _______________________________________________________________________
    
    {bcolors.WARNING}¡Oh no! You made the wrong choice!
    
    {bcolors.HEADER} The old person is pointing you with a gun!!
    you are completely stunned, the old person shoots you, takes your money 
    and leaves!!

    {bcolors.BOLD}{bcolors.OKCYAN}G A M E    O V E R   !!  
    _______________________________________________________________________ 
     
    """)
    play_again()

#Play again option
def play_again():
    play = input(" Want to play again? (yes/no) ")
    play = play.casefold()
    
    if "yes"in play:
        print("Great! Lets go back to the beginnig.")
        input("Press Enter when ready")
        user_name()
    
    elif "no" in play:
        fail_1() 
    
    else:
        print(f"{bcolors.WARNING}Invalid entry. Please try again.")
        play_again()

# %%
def stage_2(pocket, user):
    
        #Visual Effect for the into
    telon = 2
    t=0.3

    while telon > 0:
        print(".")
        time.sleep(0.3)
        print(".")
        time.sleep( 0.3 )
        telon -=1
    time.sleep(0.3)
    print(f"""{bcolors.OKCYAN} You made it to stage 2 - Nice work! .""")
    time.sleep(0.3)
    print(f"""{bcolors.OKGREEN}That same night {user} went to party with friends, hoping to feel better.""")
    time.sleep(t)
    print(f"""{bcolors.OKGREEN} When {user} arrives to the party, Roxanne, a {user}'s best friend approaches'""")
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Roxanne:{bcolors.HEADER} Heeyyyyy!!! Where were you {user}!! I was so worried! """)
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Roxanne:{bcolors.HEADER} Sorry about your break up.... But don´t worry, let's play a game and have fun! """)
    time.sleep(t)
    print(f"""{bcolors.OKGREEN} 
    
    Roxxanne takes you a table where you see a lot of tequila shots. Roxanne and you are standing back to back.
    Everytime turn you have to choose a side to look, as well as Roxanne, every time you guess the same side,
    you will take a shot of tequila, every time you don't guess the same side, you avoid the tequila shot.
    
    Be aware that if you drink more tequilas than you should you might get drunk!
    """)
    
    input("Press enter when ready!")
    
    import random    
    turn = 5
    tequilas = 0
    notequilas = 0
    Game =["right","left"]

    while turn > 0:
        Game =["right","left"]
        print(f"##### TURN {turn} ##### ")
        choose = input("Choose Right or Left?")
        choose = choose.casefold()
        roxanne = random.choice(Game)


        if choose == roxanne:
            tequilas +=1
            print(f"The score is {user} {tequilas} - Roxanne {notequilas} ")
            turn=turn-1   

        elif choose != "right" and choose != "left":
            print(" Invalid entry. Try Again")

        else:
            notequilas +=1
            print(f"The score is {user} {tequilas} - Roxanne {notequilas} ")
            turn=turn-1

    if tequilas < notequilas:
        fail_4()

    else:

        print(f"""{bcolors.OKBLUE}Roxanne:{bcolors.HEADER} A W E S O M E {user}!! You just rock the party! """)
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}Roxanne:{bcolors.HEADER} Let's go dancing! """)
        time.sleep(t)
        print(f"""{bcolors.OKGREEN} 

        Roxanne takes you to dance reggeaton with her. You dance closely, you are having a great time.
        When dancing a slow song, you get really close to Roxanne. 

        """)
        time.sleep(t)

        kiss = input(prompt = "Will you kiss Roxanne? (Yes/No) ")
        kiss = kiss.casefold()

        if "yes" in kiss:
            fail_5()

        else:
            print(f"""{bcolors.OKGREEN} 

       You stop dancing and tell Roxanne you need to go home! She insist for you to stay, but 
       you leave the party. By then, your mobile is dead, so you decide to walk home. 

        """)
            stage_3(pocket, user)
    
def fail_4():
    #Wrong choice! 
    print(f"""
    _______________________________________________________________________
    
    {bcolors.WARNING} Oh no! You drank to many Tequilas, know you are drunk
    
    {bcolors.HEADER} You got so drunk you throw up in the restroom and fall asleep in the sofá.
     Everyone painted your face with black marker. You woke up, wasted and still broken hearted.
     
    {bcolors.BOLD}{bcolors.OKCYAN}G A M E    O V E R   !!  
    _______________________________________________________________________ 
     
    """)
    
    play_again()
    
def fail_5():
    #Wrong choice! 
    print(f"""
    _______________________________________________________________________
    
    {bcolors.OKBLUE}Roxanne:{bcolors.HEADER} What is wrong with you! We are just friends! 
    
    {bcolors.HEADER} Music stops! You and Roxanne felt so awkward that you decided to take an Uber back home.
    You feel so dumb, now you mess up thing with your best friend too!
     
    {bcolors.BOLD}{bcolors.OKCYAN}G A M E    O V E R   !!  
    _______________________________________________________________________ 
     
    """)
    
    play_again()

# %%
#Move to Stage 1 
def stage_1(user):
    t=0.3
    #Old Person dialogues 
    print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER}Thank you! I been walking for a while, my legs hurt.""")
    time.sleep(t)
    
    print(f"""{bcolors.OKGREEN} The Old Person sits next to you.  """)
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER}You look familiar to me? Did we meet before?""")
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER} ... ... ....""")
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER}
    
    You are the guy that gave us food for free last park charity event!
    You and that other person... weren't you a couple? """)
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER} Are you still together?""")
    time.sleep(t)
    question_1()
    choice_1(user)

def pocket_1():
    pocket = ["ring"]

def pocket_2():
    pocket = ["empty"]
    
def choice_1(user):
    pocket = []
    ring = input("Do yo want to keep ring? (yes/no) ")
    ring = ring.casefold()
    
    if "yes" in ring:
        pocket.append("ring")
        print(f"{bcolors.OKGREEN}You have put the ring inside your pocket. ")
        print(f"Pocket = {pocket}")
        stage_2(pocket,user)
        
    elif "no" in ring:
        pocket.append("empty")
        print(f"{bcolors.OKGREEN}You looked the ring, walk towards the park bridge, you close your eyes, breath, and then you throw the ring to the river. ")
        stage_2(pocket,user)
        
    else:
        print(f"{bcolors.WARNING}Invalid entry. Please try typing >start< again.\n")
        choice_1()
    
def question_1():
    t=0.3
    
    #Firt stage question
    
    qst_1 = input(prompt ="What to talk this stranger about your break up? (yes/no)")
    qst_1 = qst_1.casefold()
    
    #yes ---> Old person advice and gift
    if "yes" in qst_1:
        
        telon = 2
        while telon > 0:
            print(".")
            time.sleep(0.3)
            print(".")
            time.sleep( 0.3 )
            telon -=1
          
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER} Wow! I am sorry to hear this!""")
        time.sleep(t)
        
        print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER} Let me give you an advice...
        
        Yesterday is history, tomorrow is a mistery, but today is a gift, that is why it's called "The present".
        
        What I mean, stop regretting and overthink, live your present and enjoy life as it comes!
        
        Take this gift as a reminder. 
        
        """)
        
        time.sleep(t) 
        
        print(f"""{bcolors.OKGREEN} The Old Person gives you somthing and leaves. You open the present. It's a ring! """)
    
        time.sleep(t)
    #no ---> Old Person recognize you, dont want to make you unconfortable and leaves.
    elif "no" in qst_1:
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}Old Person: {bcolors.HEADER} I see, well I have to move on! Have a great day!""")
        time.sleep(t)
        fail_3()
    #Type a normal response
    else:
        print(f"{bcolors.WARNING}Invalid entry. Please try typing again.\n")
        question_1()

def fail_3():
    #Wrong choice! 
    print(f"""
    _______________________________________________________________________
    
    {bcolors.WARNING} :S You made the wrong choice!
    
    {bcolors.HEADER} The old person goes away! You stay confuse in the bench, remembering that special person,
     after inner reflexion you decide to go back home with your heatache. 
     
    {bcolors.BOLD}{bcolors.OKCYAN}G A M E    O V E R   !!  
    _______________________________________________________________________ 
     
    """)
    
    play_again()

# %%
def stage_3(pocket, user):
    
    telon = 2
    t=0.3

    while telon > 0:
        print(".")
        time.sleep(0.3)
        print(".")
        time.sleep( 0.3 )
        telon -=1
    
    time.sleep(0.3)
    
    print(f"""{bcolors.OKCYAN} You made it to stage 3 - AMAZING! .""")
        
    print(f"""{bcolors.OKGREEN} You are almost home when you notice someone is waiting at your door.
    Could it be.... Yes, that special person is waiting for you. As your mind goes empty,
    your Ex says: """)
    
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Ex: {bcolors.HEADER} Hey! Surprise {user}! haha I just wanted to give you back this jacket""")
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Ex: {bcolors.HEADER} Okay, well here is it! ... ... .... ... """)
    time.sleep(t)
    print(f"""{bcolors.OKBLUE}Ex: {bcolors.HEADER} ... ... I guess that I should go now ... ... """)
    time.sleep(t)
    guess(pocket, user)

def guess(pocket, user):
    
    t=0.3
    stay = input(prompt="Do you want her to stay? (yes/no)")
    stay = stay.casefold()
        
    if "yes" in stay:
        fail_6(user)
            
    elif "no" in stay:    
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}Ex: {bcolors.HEADER} .... wait ! ...... Everything is so confusing!.... what I am trying to say...""")
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}You: {bcolors.HEADER} I am sorry? """)
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}Ex: {bcolors.HEADER} Yes! I am sorry, I never met to hurt you""")
        time.sleep(t)
        print(f""" {bcolors.OKGREEN} You look down. You remember something... """)
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}You: {bcolors.HEADER} Past is histoy, tomorrow is mistery... but today, today is a gift.
        That's why it's called present!... Take this with you so you don't forget...""")
        z(pocket, user)
            
        
    else:
        print(f"{bcolors.WARNING}Invalid entry. Please try again.")
        guess(pocket, user)

            
    
            
def fail_6(user):
    #Wrong choice! 
    print(f"""
    _______________________________________________________________________
    {bcolors.OKBLUE}{user}: {bcolors.HEADER} Hey do you want to come in? I can offer you a cup of tea?
    
    {bcolors.OKBLUE}Ex: {bcolors.HEADER} ...Okay... ??? It's like midnight, I better go home now
    
    {bcolors.HEADER} She is so confused, she runs backhome crying... You are confused as well, so you get in your home,
    with the jacket. 
     
    {bcolors.BOLD}{bcolors.OKCYAN}G A M E    O V E R   !!  
    _______________________________________________________________________ 
     
    """)
    
    play_again()
    

def fail_7():
    #Wrong choice! 
    print(f"""
    _______________________________________________________________________

    {bcolors.OKGREEN} Oh no! You drop the ring in the river! Your Ex believes 
    this is a bad joke. She slaps you in the face and goes away mad at you.
     
    {bcolors.BOLD}{bcolors.OKCYAN}G A M E    O V E R   !!  
    _______________________________________________________________________ 
    
    """)
    play_again()

def z(pocket, user):
    x = input("Do you want to give her the ring? Type ring ")
    x = x.casefold()
    y = pocket[0]
    t=0.3
    
    if "ring" in x and "ring" in y:
        print(f""" {bcolors.OKGREEN} You take the {pocket} from your pocket and give it to her. """)
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}You: {bcolors.HEADER} Do what you need to do now, if we are meant to be, will be! """)
        time.sleep(t)
        print(f"""{bcolors.OKBLUE}Ex: {bcolors.HEADER} Oh... {user}... Thanks """)
        time.sleep(t)
        print(f""" {bcolors.OKGREEN} He kisses you in the cheek, says goodbye and leaves """)
        time.sleep(t)
        print(f""" {bcolors.OKCYAN} 
        
        
        CONGRATULATIONs! Even though you still have a heart broken, you made all the right
        choices back home. Life is not always fair, but you should always be aware that own
        your present, live in the past, dont over think the future, live your present!
        
        Thanks for playing :D""")

    elif "ring" in x and "empty" in y:
        fail_7()

    else:
        print(f"{bcolors.WARNING}Invalid entry. Please try again.")
        z(pocket, user)

# %%
press_start()
